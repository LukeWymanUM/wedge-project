# %% [markdown]
# # Wedge Task 1

# %%
import os
import zipfile
import pandas as pd
from collections import Counter
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from google.cloud import bigquery

# %%
data_directory = "data/WedgeZipOfZips_small/"

# %%
for file in os.listdir(data_directory):
    print(file)
# Out:
# transArchive_201310_201312_small.zip
# transArchive_201207_201209_small.zip
# transArchive_201204_201206_inactive_small.zip
# transArchive_201304_201306_inactive_small.zip
# transArchive_201007_201009_small.zip
# transArchive_201105_small.zip
# transArchive_201110_201112_small.zip
# transArchive_201304_201306_small.zip
# transArchive_201404_201406_inactive_small.zip
# transArchive_201504_201506_small.zip
# .DS_Store
# transArchive_201612_small.zip
# transArchive_201606_small.zip
# transArchive_201401_201403_inactive_small.zip
# transArchive_201407_201409_small.zip
# transArchive_201201_201203_inactive_small.zip
# transArchive_201301_201303_inactive_small.zip
# transArchive_201310_201312_inactive_small.zip
# transArchive_201107_201109_small.zip
# transArchive_201601_small.zip
# transArchive_201210_201212_inactive_small.zip
# transArchive_201010_201012_small.zip
# transArchive_201204_201206_small.zip
# transArchive_201410_201412_inactive_small.zip
# transArchive_201210_201212_small.zip
# transArchive_201104_small.zip
# transArchive_201307_201309_small.zip
# transArchive_201512_small.zip
# transArchive_201004_201006_small.zip
# transArchive_201207_201209_inactive_small.zip
# transArchive_201307_201309_inactive_small.zip
# transArchive_201507_201509_small.zip
# transArchive_201607_small.zip
# transArchive_201410_201412_small.zip
# transArchive_201404_201406_small.zip
# transArchive_201407_201409_inactive_small.zip
# transArchive_201602_small.zip
# transArchive_201301_201303_small.zip
# transArchive_201101_201103_small.zip
# transArchive_201511_small.zip
# transArchive_201610_small.zip
# transArchive_201604_small.zip
# transArchive_201501_201503_small.zip
# transArchive_201609_small.zip
# transArchive_201001_201003_small.zip
# transArchive_201603_small.zip
# transArchive_201106_small.zip
# transArchive_201201_201203_small.zip
# transArchive_201510_small.zip
# transArchive_201605_small.zip
# transArchive_201401_201403_small.zip
# transArchive_201611_small.zip
# transArchive_201608_small.zip
# transArchive_201701_small.zip

# %%
with zipfile.ZipFile(data_directory+file) as my_zip:
    for zipped_file in my_zip.namelist():
        x=my_zip.extract(zipped_file)
        print(x)
# Out:
# /Users/lukewyman/github-classroom/bmkt670-ada-2024fall/wedge-project/transArchive_201701_small.csv

# %%
def unpack_zip(zip_file_path):
    with zipfile.ZipFile(zip_file_path, 'r') as Z:
        file = Z.namelist()[0]

        with Z.open(file) as csv_file:
            contents = pd.read_csv(csv_file)
            
            return file, contents

# %%
def to_folder(zip_file_path, output_directory):
    with zipfile.ZipFile(zip_file_path, 'r') as Z:

        file = Z.namelist()[0]

        # Create output directory if it doesn't exist
        if not os.path.exists(output_directory):
            os.makedirs(output_directory)

        # Extract the CSV file to the output directory
        Z.extract(file, path=output_directory)
        return file

# %%
# Get the zip file path from the data directory and the zip file
def get_file_path(data_directory, file):
    file_path = data_directory+file
    return file_path

# %%
data_directory = "data/WedgeZipOfZips_small/"
csv_directory = "data/WedgeCSVs/"
csv_data_dict = {}

for zip_file in os.listdir(data_directory):
    if zip_file.endswith('.zip'):
        
        zip_file_path = get_file_path(data_directory, zip_file)

        file, contents = unpack_zip(zip_file_path)
        # Add the CSV filename and contents to the dictionary
        csv_data_dict[file] = contents

        to_folder(zip_file_path,csv_directory)
    else:
        pass

# %% [markdown]
# # Header Validation

# %%
def get_headers(csv_directory):
    headers = []
    for csv_file in os.listdir(csv_directory):

        csv_file_path = get_file_path(csv_directory, csv_file)

        df = pd.read_csv(csv_file_path, nrows=0)  # Read only the header

        headers.append(tuple(df.columns))  # Store the header as a tuple

    headers_df = pd.DataFrame(Counter(headers).items(), columns=['Header', 'Count']).sort_values(by='Count', ascending=False)
    
    return headers_df

# %%
headers_df = get_headers(csv_directory)

# %%
headers_df
# Out:
#                                                Header  Count
# 3   (datetime, register_no, emp_no, trans_no, upc,...     26
# 1   (datetime;"register_no";"emp_no";"trans_no";"u...     12
# 0   (2016-12-01 07:43:01, 51, 94, 23, 000000000004...      1
# 2   (2016-06-01 08:04:44, 51, 94, 41, 000000000015...      1
# 4   (2016-07-01 07:06:15, 51, 94, 1, 0065722700050...      1
# 5   (2016-01-01 09:12:14, 51, 94, 3, 0000000000039...      1
# 6   (2015-12-01 07:03:06, 51, 94, 2, TAX, Tax, A, ...      1
# 7   (2016-10-01 07:04:40, 51, 94, 1, DISCOUNT, Dis...      1
# 8   (2016-04-01 07:34:35, 51, 94, 18, 0, Cash, T, ...      1
# 9   (2016-09-01 07:13:09, 51, 94, 6, 0, Change, T,...      1
# 10  (2016-02-01 07:16:56, 51, 94, 3, TAX, Tax, A, ...      1
# 11  (2015-11-01 07:21:50, 51, 94, 4, TAX, Tax, A, ...      1
# 12  (2016-05-01 11:23:35, 51, 94, 113, 00000000043...      1
# 13  (2016-11-01 07:18:44, 51, 94, 11, 000000000101...      1
# 14  (2017-01-01 09:00:31, 51, 94, 12, 0, Change, T...      1
# 15  (2016-08-01 07:34:16, 51, 94, 7, 0000000000151...      1
# 16  (2016-03-01 07:04:38, 51, 94, 2, TAX, Tax, A, ...      1

# %%
print(headers_df.iloc[0,0])
print(headers_df.iloc[1,0])
# Out:
# ('datetime', 'register_no', 'emp_no', 'trans_no', 'upc', 'description', 'trans_type', 'trans_subtype', 'trans_status', 'department', 'quantity', 'Scale', 'cost', 'unitPrice', 'total', 'regPrice', 'altPrice', 'tax', 'taxexempt', 'foodstamp', 'wicable', 'discount', 'memDiscount', 'discountable', 'discounttype', 'voided', 'percentDiscount', 'ItemQtty', 'volDiscType', 'volume', 'VolSpecial', 'mixMatch', 'matched', 'memType', 'staff', 'numflag', 'itemstatus', 'tenderstatus', 'charflag', 'varflag', 'batchHeaderID', 'local', 'organic', 'display', 'receipt', 'card_no', 'store', 'branch', 'match_id', 'trans_id')
# ('datetime;"register_no";"emp_no";"trans_no";"upc";"description";"trans_type";"trans_subtype";"trans_status";"department";"quantity";"Scale";"cost";"unitPrice";"total";"regPrice";"altPrice";"tax";"taxexempt";"foodstamp";"wicable";"discount";"memDiscount";"discountable";"discounttype";"voided";"percentDiscount";"ItemQtty";"volDiscType";"volume";"VolSpecial";"mixMatch";"matched";"memType";"staff";"numflag";"itemstatus";"tenderstatus";"charflag";"varflag";"batchHeaderID";"local";"organic";"display";"receipt";"card_no";"store";"branch";"match_id";"trans_id"',)

# %% [markdown]
# Looks like we have differently delimited files.

# %%
for csv_file in os.listdir(csv_directory):

    csv_file_path = get_file_path(csv_directory, csv_file)
    
    # Determine the current delimiter by checking the first line of the file
    with open(csv_file_path, 'r') as f:
        first_line = f.readline().strip()
        current_delimiter = ',' if ',' in first_line else ';'
        
    # Read the CSV file with the current delimiter
    df = pd.read_csv(csv_file_path, delimiter=current_delimiter)
        
    # Save the file back with a semicolon (;) delimiter
    df.to_csv(csv_file_path, sep=';', index=False)

# %%
headers_df = get_headers(csv_directory)
headers_df
# Out:
#                                                Header  Count
# 1   (datetime;register_no;emp_no;trans_no;upc;desc...     38
# 0   (2016-12-01 07:43:01;51;94;23;0000000000049;We...      1
# 2   (2016-06-01 08:04:44;51;94;41;0000000000151;Ba...      1
# 3   (2016-07-01 07:06:15;51;94;1;0065722700050;Ele...      1
# 4   (2016-01-01 09:12:14;51;94;3;0000000000039;Wed...      1
# 5   (2015-12-01 07:03:06;51;94;2;TAX;Tax;A;Unnamed...      1
# 6   (2016-10-01 07:04:40;51;94;1;DISCOUNT;Discount...      1
# 7   (2016-04-01 07:34:35;51;94;18;0;Cash;T;CA;Unna...      1
# 8   (2016-09-01 07:13:09;51;94;6;0;Change;T;CA;Unn...      1
# 9   (2016-02-01 07:16:56;51;94;3;TAX;Tax;A;Unnamed...      1
# 10  (2015-11-01 07:21:50;51;94;4;TAX;Tax;A;Unnamed...      1
# 11  (2016-05-01 11:23:35;51;94;113;0000000004365;B...      1
# 12  (2016-11-01 07:18:44;51;94;11;0000000001014;Gr...      1
# 13  (2017-01-01 09:00:31;51;94;12;0;Change;T;CA;Un...      1
# 14  (2016-08-01 07:34:16;51;94;7;0000000000151;Ban...      1
# 15  (2016-03-01 07:04:38;51;94;2;TAX;Tax;A;Unnamed...      1

# %% [markdown]
# We still have multiple data sets that don't have a header. To alleviate this, we will functionally add headers to data sets that do not have headers. We do this by comparing the header to the most common header. If the header is not the same as the most common header, we create a new data set with that header, append the data, and replace the file that didn't initially have the header.

# %%
most_common_header = headers_df.iloc[0,0]

for csv_file in os.listdir(csv_directory):

    csv_file_path = get_file_path(csv_directory, csv_file)
    
    # Read the CSV file 
    df = pd.read_csv(csv_file_path)
        
    # Check if the first row matches the most common header
    if tuple(df.columns) != most_common_header:
        df = pd.read_csv(csv_file_path, header=None)
        df.columns = list(most_common_header)
        # Overwrite the original CSV file with the new header
        df.to_csv(csv_file_path, index=False)  # index=False to avoid writing row numbers

# %%
headers_df = get_headers(csv_directory)
headers_df
# Out:
#                                               Header  Count
# 0  (datetime;register_no;emp_no;trans_no;upc;desc...     53

# %% [markdown]
# Sweet, so now we have all of the csv files with common headers.
# # Double Quotation Handling

# %%
def remove_double_quotes(csv_directory):
    for csv_file in os.listdir(csv_directory):
        csv_file_path = os.path.join(csv_directory, csv_file)

        # Read the CSV file as a raw text file to handle quotes more flexibly
        with open(csv_file_path, 'r', encoding='utf-8') as file:
            content = file.readlines()  # Read lines instead of the entire content

        # Remove all double quotes and trim trailing semicolons
        cleaned_content = []
        for line in content:
            line = line.replace('"', '').rstrip()  # Remove double quotes and trailing whitespace
            if line.endswith(';'):
                line = line[:-1]  # Remove the last semicolon if it exists
            cleaned_content.append(line + '\n')  # Add newline back

        # Write the cleaned content back to the CSV file
        with open(csv_file_path, 'w', encoding='utf-8') as file:
            file.writelines(cleaned_content)  # Write the modified lines

# %%
remove_double_quotes(csv_directory)

# %% [markdown]
# # Investigating Data Types

# %%
def get_datatypes(csv_directory):
    datatypes = []
    for csv_file in os.listdir(csv_directory):

        csv_file_path = get_file_path(csv_directory, csv_file)

        df = pd.read_csv(csv_file_path, delimiter=";", low_memory=False)  

        datatypes.append(tuple(df.dtypes))

    datatypes_df = pd.DataFrame(Counter(datatypes).items(), columns=['Header', 'Count']).sort_values(by='Count', ascending=False)
    
    return datatypes_df

# %%
datatypes_df = get_datatypes(csv_directory)
datatypes_df
# Out:
#                                                Header  Count
# 4   (object, int64, int64, int64, object, object, ...     14
# 1   (object, int64, int64, int64, object, object, ...      6
# 5   (object, int64, int64, int64, object, object, ...      6
# 3   (object, int64, int64, int64, object, object, ...      5
# 7   (object, int64, int64, int64, object, object, ...      4
# 6   (object, int64, int64, int64, object, object, ...      2
# 2   (object, int64, int64, int64, object, object, ...      1
# 0   (object, int64, int64, int64, object, object, ...      1
# 8   (object, int64, int64, int64, object, object, ...      1
# 9   (object, int64, int64, int64, object, object, ...      1
# 10  (object, int64, int64, int64, object, object, ...      1
# 11  (object, int64, int64, int64, object, object, ...      1
# 12  (object, int64, int64, int64, object, object, ...      1
# 13  (object, int64, int64, int64, object, object, ...      1
# 14  (object, int64, int64, int64, object, object, ...      1
# 15  (object, int64, int64, int64, object, object, ...      1
# 16  (object, int64, int64, int64, object, object, ...      1
# 17  (object, int64, int64, int64, object, object, ...      1
# 18  (object, int64, int64, int64, object, object, ...      1
# 19  (object, int64, int64, int64, object, object, ...      1
# 20  (object, int64, int64, int64, object, object, ...      1
# 21  (object, int64, int64, int64, object, object, ...      1

# %% [markdown]
# It seems that not every data set has the same data type. So, we need to identify where we are having differences and make the appropriate changes.

# %%
def get_datatypes_df(csv_directory):
    datatypes_list = [] 
    for csv_file in os.listdir(csv_directory):

        csv_file_path = get_file_path(csv_directory, csv_file)

        df = pd.DataFrame(pd.read_csv(csv_file_path, delimiter=";", low_memory=False))  
        
        datatypes_list.append(df.dtypes)

    datatypes_df = pd.DataFrame(datatypes_list)

    return datatypes_df

# %%
datatypes_df = get_datatypes_df(csv_directory)
datatypes_df['display']
# Out:
# 0      object
# 1      object
# 2      object
# 3     float64
# 4      object
# 5     float64
# 6      object
# 7      object
# 8      object
# 9      object
# 10     object
# 11     object
# 12    float64
# 13     object
# 14    float64
# 15     object
# 16     object
# 17    float64
# 18    float64
# 19     object
# 20     object
# 21    float64
# 22    float64
# 23     object
# 24     object
# 25     object
# 26     object
# 27     object
# 28    float64
# 29    float64
# 30    float64
# 31     object
# 32     object
# 33     object
# 34     object
# 35     object
# 36     object
# 37    float64
# 38     object
# 39     object
# 40     object
# 41     object
# 42     object
# 43     object
# 44    float64
# 45     object
# 46     object
# 47     object
# 48    float64
# 49     object
# 50     object
# 51     object
# 52    float64
# Name: display, dtype: object

# %%
def check_common_datatype(csv_directory):
    datatypes_df = get_datatypes_df(csv_directory)
    
    common_dtype_dict = {}

    for column in datatypes_df.columns:
        common_dtype = datatypes_df[column].mode()[0]
        common_dtype_dict[column] = common_dtype

    return common_dtype_dict

# %%
dtype_mapping = check_common_datatype(csv_directory)
dtype_mapping
# Out:
# {'datetime': dtype('O'),
#  'register_no': dtype('int64'),
#  'emp_no': dtype('int64'),
#  'trans_no': dtype('int64'),
#  'upc': dtype('O'),
#  'description': dtype('O'),
#  'trans_type': dtype('O'),
#  'trans_subtype': dtype('O'),
#  'trans_status': dtype('O'),
#  'department': dtype('int64'),
#  'quantity': dtype('float64'),
#  'Scale': dtype('int64'),
#  'cost': dtype('float64'),
#  'unitPrice': dtype('float64'),
#  'total': dtype('float64'),
#  'regPrice': dtype('float64'),
#  'altPrice': dtype('float64'),
#  'tax': dtype('int64'),
#  'taxexempt': dtype('float64'),
#  'foodstamp': dtype('int64'),
#  'wicable': dtype('int64'),
#  'discount': dtype('float64'),
#  'memDiscount': dtype('float64'),
#  'discountable': dtype('int64'),
#  'discounttype': dtype('int64'),
#  'voided': dtype('int64'),
#  'percentDiscount': dtype('float64'),
#  'ItemQtty': dtype('float64'),
#  'volDiscType': dtype('int64'),
#  'volume': dtype('int64'),
#  'VolSpecial': dtype('float64'),
#  'mixMatch': dtype('int64'),
#  'matched': dtype('int64'),
#  'memType': dtype('float64'),
#  'staff': dtype('float64'),
#  'numflag': dtype('int64'),
#  'itemstatus': dtype('float64'),
#  'tenderstatus': dtype('float64'),
#  'charflag': dtype('O'),
#  'varflag': dtype('int64'),
#  'batchHeaderID': dtype('float64'),
#  'local': dtype('float64'),
#  'organic': dtype('float64'),
#  'display': dtype('O'),
#  'receipt': dtype('float64'),
#  'card_no': dtype('int64'),
#  'store': dtype('int64'),
#  'branch': dtype('int64'),
#  'match_id': dtype('float64'),
#  'trans_id': dtype('int64')}

# %%
def fix_datatypes(csv_directory, mapping=None):
    needing_changed = 0
    for csv_file in os.listdir(csv_directory):

        csv_file_path = get_file_path(csv_directory, csv_file)
        
        try:
            df = pd.read_csv(csv_file_path, delimiter=";", dtype=mapping)  
            
            print(csv_file)
            print('-------')
            
            for column in df.columns:
                if df[column].dtype != dtype_mapping[column]:
                    print(f"{column}: {df[column].dtype} should be converted to {dtype_mapping[column]}.")
                    needing_changed += 1
        except Exception as e:
            print(f"Error reading {csv_file}: {e}")

    return f"{needing_changed} fields need changed."

# %%
fix_datatypes(csv_directory)
# Out:
# transArchive_201612_small.csv
# -------
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# memDiscount: object should be converted to float64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# store: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201401_201403_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201606_small.csv
# -------
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# ItemQtty: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# store: float64 should be converted to int64.
# match_id: object should be converted to float64.
# trans_id: float64 should be converted to int64.
# transArchive_201504_201506_small.csv
# -------
# wicable: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# display: float64 should be converted to object.
# transArchive_201201_201203_inactive_small.csv
# -------
# transArchive_201407_201409_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201301_201303_inactive_small.csv
# -------
# memType: object should be converted to float64.
# transArchive_201204_201206_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201304_201306_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201310_201312_small.csv
# -------
# memType: object should be converted to float64.
# transArchive_201207_201209_small.csv
# -------
# transArchive_201304_201306_small.csv
# -------
# transArchive_201404_201406_inactive_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201105_small.csv
# -------
# transArchive_201007_201009_small.csv
# -------
# taxexempt: int64 should be converted to float64.
# staff: int64 should be converted to float64.
# itemstatus: int64 should be converted to float64.
# tenderstatus: int64 should be converted to float64.
# local: int64 should be converted to float64.
# display: float64 should be converted to object.
# receipt: int64 should be converted to float64.
# match_id: int64 should be converted to float64.
# transArchive_201110_201112_small.csv
# -------
# transArchive_201607_small.csv
# -------
# department: float64 should be converted to int64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# card_no: float64 should be converted to int64.
# store: float64 should be converted to int64.
# branch: float64 should be converted to int64.
# match_id: object should be converted to float64.
# trans_id: float64 should be converted to int64.
# transArchive_201507_201509_small.csv
# -------
# wicable: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# display: float64 should be converted to object.
# transArchive_201410_201412_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201207_201209_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201307_201309_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201404_201406_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201407_201409_inactive_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201204_201206_small.csv
# -------
# transArchive_201310_201312_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201601_small.csv
# -------
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# wicable: object should be converted to int64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# card_no: float64 should be converted to int64.
# store: float64 should be converted to int64.
# branch: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201107_201109_small.csv
# -------
# transArchive_201210_201212_inactive_small.csv
# -------
# Scale: float64 should be converted to int64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: float64 should be converted to int64.
# discountable: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# numflag: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# card_no: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201010_201012_small.csv
# -------
# taxexempt: int64 should be converted to float64.
# staff: int64 should be converted to float64.
# itemstatus: int64 should be converted to float64.
# tenderstatus: int64 should be converted to float64.
# local: int64 should be converted to float64.
# display: float64 should be converted to object.
# receipt: int64 should be converted to float64.
# match_id: int64 should be converted to float64.
# transArchive_201004_201006_small.csv
# -------
# taxexempt: int64 should be converted to float64.
# staff: int64 should be converted to float64.
# itemstatus: int64 should be converted to float64.
# tenderstatus: int64 should be converted to float64.
# local: int64 should be converted to float64.
# display: float64 should be converted to object.
# receipt: int64 should be converted to float64.
# match_id: int64 should be converted to float64.
# transArchive_201410_201412_inactive_small.csv
# -------
# wicable: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# display: float64 should be converted to object.
# transArchive_201210_201212_small.csv
# -------
# transArchive_201104_small.csv
# -------
# transArchive_201307_201309_small.csv
# -------
# transArchive_201512_small.csv
# -------
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# organic: object should be converted to float64.
# branch: float64 should be converted to int64.
# transArchive_201610_small.csv
# -------
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# store: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201604_small.csv
# -------
# department: float64 should be converted to int64.
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# match_id: object should be converted to float64.
# transArchive_201501_201503_small.csv
# -------
# wicable: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# display: float64 should be converted to object.
# transArchive_201609_small.csv
# -------
# department: float64 should be converted to int64.
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# match_id: object should be converted to float64.
# transArchive_201602_small.csv
# -------
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# card_no: float64 should be converted to int64.
# branch: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201301_201303_small.csv
# -------
# transArchive_201511_small.csv
# -------
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# match_id: object should be converted to float64.
# transArchive_201101_201103_small.csv
# -------
# transArchive_201605_small.csv
# -------
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# store: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201401_201403_small.csv
# -------
# display: float64 should be converted to object.
# transArchive_201611_small.csv
# -------
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# organic: object should be converted to float64.
# store: float64 should be converted to int64.
# transArchive_201701_small.csv
# -------
# department: float64 should be converted to int64.
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# match_id: object should be converted to float64.
# trans_id: float64 should be converted to int64.
# transArchive_201608_small.csv
# -------
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# ItemQtty: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# organic: object should be converted to float64.
# store: float64 should be converted to int64.
# trans_id: float64 should be converted to int64.
# transArchive_201001_201003_small.csv
# -------
# taxexempt: int64 should be converted to float64.
# staff: int64 should be converted to float64.
# itemstatus: int64 should be converted to float64.
# tenderstatus: int64 should be converted to float64.
# local: int64 should be converted to float64.
# display: float64 should be converted to object.
# receipt: int64 should be converted to float64.
# match_id: int64 should be converted to float64.
# transArchive_201603_small.csv
# -------
# Scale: float64 should be converted to int64.
# unitPrice: object should be converted to float64.
# total: object should be converted to float64.
# regPrice: object should be converted to float64.
# altPrice: object should be converted to float64.
# tax: float64 should be converted to int64.
# taxexempt: object should be converted to float64.
# foodstamp: float64 should be converted to int64.
# wicable: object should be converted to int64.
# discount: object should be converted to float64.
# memDiscount: object should be converted to float64.
# discountable: float64 should be converted to int64.
# discounttype: float64 should be converted to int64.
# voided: float64 should be converted to int64.
# percentDiscount: object should be converted to float64.
# volDiscType: float64 should be converted to int64.
# volume: float64 should be converted to int64.
# VolSpecial: object should be converted to float64.
# mixMatch: float64 should be converted to int64.
# matched: float64 should be converted to int64.
# memType: object should be converted to float64.
# staff: object should be converted to float64.
# numflag: float64 should be converted to int64.
# itemstatus: object should be converted to float64.
# tenderstatus: object should be converted to float64.
# varflag: object should be converted to int64.
# batchHeaderID: object should be converted to float64.
# local: object should be converted to float64.
# organic: object should be converted to float64.
# receipt: object should be converted to float64.
# branch: float64 should be converted to int64.
# match_id: object should be converted to float64.
# transArchive_201106_small.csv
# -------
# transArchive_201201_201203_small.csv
# -------
# transArchive_201510_small.csv
# -------
# wicable: float64 should be converted to int64.
# varflag: float64 should be converted to int64.
# display: float64 should be converted to object.
# '590 fields need changed.'

# %%
def change_datatypes(csv_directory):

    for csv_file in os.listdir(csv_directory):

        csv_file_path = get_file_path(csv_directory, csv_file)
        
        df = pd.read_csv(csv_file_path, delimiter=";")  

        df['display'] = ''
        print(csv_file)
        print('-------')
            
        for column in df.columns:
            if df[column].dtype == dtype_mapping[column]:
                continue

            # Perform the conversion based on target type
            try:
                if dtype_mapping[column] == 'object':
                    df[column] = df[column].replace({
                        '\\N': '',
                        '\\N.1': '',
                        '\\N.2': '',
                        '\\N.3': ''
                        })
                    # to an object
                    df[column] = df[column].astype('object')
                elif dtype_mapping[column] == 'float64':
                    # Ensure the column is treated as string first
                    if df[column].dtype != 'object':
                        df[column] = df[column].astype('str')
                    
                    # modifies any places where we have strings that look like 2.4900.1
                    df[column] = df[column].str.replace(r'\.(\d{2}|\d{4})\.\d', r'.\1', regex=True)
                    df[column] = df[column].replace({
                        '\\N': 0,
                        '\\N.1': 0,
                        '\\N.2': 0,
                        '\\N.3': 0,
                        '\\N.4': 0,
                        '\\N.5': 0,
                        '\\N.6': 0,
                        ' ': 0})
                    if df[column].dtype == 'object':
                        # Replace "Unnamed" with 0.0 only if the column is of type object
                        df[column] = df[column].replace(r'.*Unnamed.*', '0.0', regex=True)
                    # to a float                    
                    df[column] = df[column].astype('float64')
                elif dtype_mapping[column] == 'int64':
                    # Ensure the column is treated as string first
                    if df[column].dtype != 'object':
                        df[column] = df[column].astype('str')
                    df[column] = df[column].replace({
                        '\\N': 0,
                        '\\N.1': 0,
                        '\\N.2': 0,
                        '\\N.3': 0,
                        '\\N.4': 0,
                        '\\N.5': 0,
                        '\\N.6': 0,
                        ' ': 0
                        })
                    # Convert to float first, then to int
                    df[column] = pd.to_numeric(df[column], errors='coerce').fillna(0).astype('float64')
                    # to an integer
                    df[column] = df[column].astype('int64')
                else:
                    print(f"{column}: Unsupported target type {dtype_mapping[column]}.")
                if df['display'].dtype == 'float64':
                    df[column] = df[column].astype('object')
                # Save the file back with a semicolon (;) delimiter
            except Exception as e:
                print(f"Error converting {column} from {df[column].dtype} to {dtype_mapping[column]}: {e}")
        # Save the file back with a semicolon (;) delimiter
        df.to_csv(csv_file_path, sep=';', index=False)
    return

# %%
change_datatypes(csv_directory)
# Out:
# transArchive_201612_small.csv
# -------
# transArchive_201401_201403_inactive_small.csv
# -------
# transArchive_201606_small.csv
# -------
# transArchive_201504_201506_small.csv
# -------
# transArchive_201201_201203_inactive_small.csv
# -------
# transArchive_201407_201409_small.csv
# -------
# transArchive_201301_201303_inactive_small.csv
# -------
# transArchive_201204_201206_inactive_small.csv
# -------
# transArchive_201304_201306_inactive_small.csv
# -------
# transArchive_201310_201312_small.csv
# -------
# transArchive_201207_201209_small.csv
# -------
# transArchive_201304_201306_small.csv
# -------
# transArchive_201404_201406_inactive_small.csv
# -------
# transArchive_201105_small.csv
# -------
# transArchive_201007_201009_small.csv
# -------
# transArchive_201110_201112_small.csv
# -------
# transArchive_201607_small.csv
# -------
# transArchive_201507_201509_small.csv
# -------
# transArchive_201410_201412_small.csv
# -------
# transArchive_201207_201209_inactive_small.csv
# -------
# transArchive_201307_201309_inactive_small.csv
# -------
# transArchive_201404_201406_small.csv
# -------
# transArchive_201407_201409_inactive_small.csv
# -------
# transArchive_201204_201206_small.csv
# -------
# transArchive_201310_201312_inactive_small.csv
# -------
# transArchive_201601_small.csv
# -------
# transArchive_201107_201109_small.csv
# -------
# transArchive_201210_201212_inactive_small.csv
# -------
# transArchive_201010_201012_small.csv
# -------
# transArchive_201004_201006_small.csv
# -------
# transArchive_201410_201412_inactive_small.csv
# -------
# transArchive_201210_201212_small.csv
# -------
# transArchive_201104_small.csv
# -------
# transArchive_201307_201309_small.csv
# -------
# transArchive_201512_small.csv
# -------
# transArchive_201610_small.csv
# -------
# transArchive_201604_small.csv
# -------
# transArchive_201501_201503_small.csv
# -------
# transArchive_201609_small.csv
# -------
# transArchive_201602_small.csv
# -------
# transArchive_201301_201303_small.csv
# -------
# transArchive_201511_small.csv
# -------
# transArchive_201101_201103_small.csv
# -------
# transArchive_201605_small.csv
# -------
# transArchive_201401_201403_small.csv
# -------
# transArchive_201611_small.csv
# -------
# transArchive_201701_small.csv
# -------
# transArchive_201608_small.csv
# -------
# transArchive_201001_201003_small.csv
# -------
# transArchive_201603_small.csv
# -------
# transArchive_201106_small.csv
# -------
# transArchive_201201_201203_small.csv
# -------
# transArchive_201510_small.csv
# -------

# %%
fix_datatypes(csv_directory, mapping=dtype_mapping)
# Out:
# transArchive_201612_small.csv
# -------
# transArchive_201401_201403_inactive_small.csv
# -------
# transArchive_201606_small.csv
# -------
# transArchive_201504_201506_small.csv
# -------
# transArchive_201201_201203_inactive_small.csv
# -------
# transArchive_201407_201409_small.csv
# -------
# transArchive_201301_201303_inactive_small.csv
# -------
# transArchive_201204_201206_inactive_small.csv
# -------
# transArchive_201304_201306_inactive_small.csv
# -------
# transArchive_201310_201312_small.csv
# -------
# transArchive_201207_201209_small.csv
# -------
# transArchive_201304_201306_small.csv
# -------
# transArchive_201404_201406_inactive_small.csv
# -------
# transArchive_201105_small.csv
# -------
# transArchive_201007_201009_small.csv
# -------
# transArchive_201110_201112_small.csv
# -------
# transArchive_201607_small.csv
# -------
# transArchive_201507_201509_small.csv
# -------
# transArchive_201410_201412_small.csv
# -------
# transArchive_201207_201209_inactive_small.csv
# -------
# transArchive_201307_201309_inactive_small.csv
# -------
# transArchive_201404_201406_small.csv
# -------
# transArchive_201407_201409_inactive_small.csv
# -------
# transArchive_201204_201206_small.csv
# -------
# transArchive_201310_201312_inactive_small.csv
# -------
# transArchive_201601_small.csv
# -------
# transArchive_201107_201109_small.csv
# -------
# transArchive_201210_201212_inactive_small.csv
# -------
# transArchive_201010_201012_small.csv
# -------
# transArchive_201004_201006_small.csv
# -------
# transArchive_201410_201412_inactive_small.csv
# -------
# transArchive_201210_201212_small.csv
# -------
# transArchive_201104_small.csv
# -------
# transArchive_201307_201309_small.csv
# -------
# transArchive_201512_small.csv
# -------
# transArchive_201610_small.csv
# -------
# transArchive_201604_small.csv
# -------
# transArchive_201501_201503_small.csv
# -------
# transArchive_201609_small.csv
# -------
# transArchive_201602_small.csv
# -------
# transArchive_201301_201303_small.csv
# -------
# transArchive_201511_small.csv
# -------
# transArchive_201101_201103_small.csv
# -------
# transArchive_201605_small.csv
# -------
# transArchive_201401_201403_small.csv
# -------
# transArchive_201611_small.csv
# -------
# transArchive_201701_small.csv
# -------
# transArchive_201608_small.csv
# -------
# transArchive_201001_201003_small.csv
# -------
# transArchive_201603_small.csv
# -------
# transArchive_201106_small.csv
# -------
# transArchive_201201_201203_small.csv
# -------
# transArchive_201510_small.csv
# -------
# '0 fields need changed.'

# %%
datatypes_df = get_datatypes_df(csv_directory)

# Initialize flag to track if any column has differing values
all_same = True

# Check if all values in each column are the same
for column in datatypes_df.columns:
    if datatypes_df[column].nunique() != 1:
        print(f"Values in column '{column}' are not the same.")
        all_same = False

# If no column with differing values was found, print all values are the same
if all_same:
    print("All values in all columns are the same.")
# Out:
# All values in all columns are the same.

# %%
# Initialize an empty list to hold DataFrames
df_list = []

# Loop through all the files in the folder
for filename in os.listdir(csv_directory):
    if filename.endswith('.csv'):  # Only process CSV files
    
        csv_file_path = get_file_path(csv_directory, csv_file)

        df = pd.DataFrame(pd.read_csv(csv_file_path, delimiter=";", low_memory=False, dtype=dtype_mapping))  
        
        # Append the DataFrame to the list
        df_list.append(df)

# Concatenate all DataFrames into one
big_df = pd.concat(df_list, ignore_index=True)
big_df['display'] = big_df['display'].fillna('')
file_name = 'data/transactions.csv'
big_df.to_csv(file_name, sep=';', index=False)

# %%
# Check and notify about datatype mismatches
for column, expected_dtype in dtype_mapping.items():
    if column in big_df.columns and str(big_df[column].dtype) != expected_dtype:
        print(f"Column '{column}': Actual type = {big_df[column].dtype}, Expected type = {expected_dtype}")

# %%
# Initialize a BigQuery client
client = bigquery.Client()

# Define the dataset and table
dataset_id = 'wedge-to-the-cloud.wedge_to_the_dataset'
table_id = 'wedge-to-the-cloud.wedge_to_the_dataset.transactions_small'

# Load data into BigQuery
job_config = bigquery.LoadJobConfig(write_disposition="WRITE_TRUNCATE")

job = client.load_table_from_dataframe(
    big_df, table_id, job_config=job_config)  # Make an API request.

job.result()  # Wait for the job to complete.
# Out:
# LoadJob<project=wedge-to-the-cloud, location=US, id=8fd76876-d80f-4fae-8fff-0fa4373943a3>
